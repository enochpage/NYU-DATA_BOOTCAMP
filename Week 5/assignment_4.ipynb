# %% [markdown]
# ##### 1050. Actors and Directors Who Cooperated At Least Three Times

# %% [markdown]
# https://leetcode.com/problems/actors-and-directors-who-cooperated-at-least-three-times/submissions/1822827181
#
# https://leetcode.com/problems/actors-and-directors-who-cooperated-at-least-three-times/submissions/1822828300

# %% [markdown]
# ##### 1667. Fix Names in a Table

# %% [markdown]
# https://leetcode.com/problems/fix-names-in-a-table/submissions/1822829023
#
# https://leetcode.com/problems/fix-names-in-a-table/submissions/1822829381

# %% [markdown]
# ##### 175. Combine Two Tables

# %% [markdown]
# https://leetcode.com/problems/combine-two-tables/submissions/1822829913
#
# https://leetcode.com/problems/combine-two-tables/submissions/1822830200

# %% [markdown]
# ##### 176. Second Highest Salary

# %% [markdown]
# https://leetcode.com/problems/second-highest-salary/submissions/1822834931
#
# https://leetcode.com/problems/second-highest-salary/submissions/1822835226

# %% [markdown]
# ##### 1327. List the Products Ordered in a Period

# %% [markdown]
# https://leetcode.com/problems/list-the-products-ordered-in-a-period/submissions/1822835645
#
# https://leetcode.com/problems/list-the-products-ordered-in-a-period/submissions/1822835927

# %% [markdown]
# ##### 1378. Replace Employee ID With The Unique Identifier

# %% [markdown]
# https://leetcode.com/problems/replace-employee-id-with-the-unique-identifier/submissions/1822836239
#
# https://leetcode.com/problems/replace-employee-id-with-the-unique-identifier/submissions/1822836474

# %% [markdown]
# ##### 550. Game Play Analysis IV

# %% [markdown]
# https://leetcode.com/problems/game-play-analysis-iv/submissions/1822836793
#
# https://leetcode.com/problems/game-play-analysis-iv/submissions/1822837098

# %% [markdown]
# ##### 1075. Project Employees I

# %% [markdown]
# https://leetcode.com/problems/project-employees-i/submissions/1822837381
#
# https://leetcode.com/problems/project-employees-i/submissions/1822837730

# %% [markdown]
# ##### 185. Department Top Three Salaries

# %% [markdown]
# https://leetcode.com/problems/department-top-three-salaries/submissions/1822838055
#
# https://leetcode.com/problems/department-top-three-salaries/submissions/1822838371
